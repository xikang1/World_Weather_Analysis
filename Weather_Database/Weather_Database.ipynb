# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
# Import the requests library.
import requests
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2dfcdc9f1731fea5b72951dd71024018

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_condition=city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current description":city_weather_condition})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | peniche
# Processing Record 4 of Set 1 | vila franca do campo
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | mae chan
# Processing Record 7 of Set 1 | egvekinot
# Processing Record 8 of Set 1 | brae
# Processing Record 9 of Set 1 | zawiyat susah
# City not found. Skipping...
# Processing Record 10 of Set 1 | atar
# Processing Record 11 of Set 1 | simav
# Processing Record 12 of Set 1 | tortoli
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | dingle
# Processing Record 15 of Set 1 | lorengau
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | bubaque
# Processing Record 21 of Set 1 | korla
# Processing Record 22 of Set 1 | cacu
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | liverpool
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | bengkulu
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | nanortalik
# Processing Record 29 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 1 | cockburn town
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | birao
# Processing Record 34 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | mount gambier
# Processing Record 39 of Set 1 | najran
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 1 | college
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | carlisle
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | vernon
# Processing Record 49 of Set 1 | guna
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | fairbanks
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | itoman
# Processing Record 7 of Set 2 | sitka
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | zhigansk
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | husavik
# Processing Record 16 of Set 2 | beringovskiy
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | karasjok
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | faanui
# Processing Record 25 of Set 2 | hovd
# Processing Record 26 of Set 2 | santa rosa
# Processing Record 27 of Set 2 | teknaf
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | cap-aux-meules
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | isangel
# Processing Record 34 of Set 2 | jalu
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | lata
# Processing Record 37 of Set 2 | klaksvik
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | antalaha
# Processing Record 40 of Set 2 | iralaya
# Processing Record 41 of Set 2 | saint anthony
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 45 of Set 2 | kusti
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | anadyr
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | saldanha
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | yarmouth
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | aranda de duero
# Processing Record 5 of Set 3 | atikokan
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | misratah
# Processing Record 9 of Set 3 | sabha
# Processing Record 10 of Set 3 | san patricio
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | onega
# Processing Record 13 of Set 3 | albion
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | batagay-alyta
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | menongue
# Processing Record 22 of Set 3 | iqaluit
# Processing Record 23 of Set 3 | sulangan
# Processing Record 24 of Set 3 | raduzhnyy
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | floro
# Processing Record 27 of Set 3 | vestmannaeyjar
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | miami
# Processing Record 30 of Set 3 | osa
# Processing Record 31 of Set 3 | bay-khaak
# Processing Record 32 of Set 3 | taoudenni
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | mount isa
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | northam
# Processing Record 37 of Set 3 | sao joao da barra
# Processing Record 38 of Set 3 | oktyabrskiy
# Processing Record 39 of Set 3 | sao filipe
# Processing Record 40 of Set 3 | laje
# Processing Record 41 of Set 3 | anchorage
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 44 of Set 3 | adrar
# Processing Record 45 of Set 3 | el corpus
# Processing Record 46 of Set 3 | stromness
# Processing Record 47 of Set 3 | maceio
# Processing Record 48 of Set 3 | qaqortoq
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | maarianhamina
# Processing Record 1 of Set 4 | challans
# Processing Record 2 of Set 4 | tselinnoye
# Processing Record 3 of Set 4 | amazar
# Processing Record 4 of Set 4 | mackenzie
# Processing Record 5 of Set 4 | storforshei
# Processing Record 6 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | bobrovskiy
# Processing Record 9 of Set 4 | port hardy
# Processing Record 10 of Set 4 | benjamin constant
# Processing Record 11 of Set 4 | borogontsy
# Processing Record 12 of Set 4 | ambilobe
# Processing Record 13 of Set 4 | gardan diwal
# City not found. Skipping...
# Processing Record 14 of Set 4 | the valley
# Processing Record 15 of Set 4 | burica
# City not found. Skipping...
# Processing Record 16 of Set 4 | saskylakh
# Processing Record 17 of Set 4 | vao
# Processing Record 18 of Set 4 | ambon
# Processing Record 19 of Set 4 | lanzhou
# Processing Record 20 of Set 4 | spiesen-elversberg
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | inhambane
# Processing Record 23 of Set 4 | narsaq
# Processing Record 24 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | capinopolis
# Processing Record 27 of Set 4 | itarema
# Processing Record 28 of Set 4 | avon park
# Processing Record 29 of Set 4 | redlands
# Processing Record 30 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 4 | axim
# Processing Record 33 of Set 4 | qasigiannguit
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | hobyo
# Processing Record 36 of Set 4 | kavaratti
# Processing Record 37 of Set 4 | ponta do sol
# Processing Record 38 of Set 4 | sambava
# Processing Record 39 of Set 4 | alofi
# Processing Record 40 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 4 | zhuhai
# Processing Record 42 of Set 4 | evensk
# Processing Record 43 of Set 4 | charlestown
# Processing Record 44 of Set 4 | swellendam
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | makat
# Processing Record 47 of Set 4 | port keats
# Processing Record 48 of Set 4 | rawson
# Processing Record 49 of Set 4 | tashtagol
# Processing Record 50 of Set 4 | biak
# Processing Record 1 of Set 5 | kantang
# Processing Record 2 of Set 5 | brigantine
# Processing Record 3 of Set 5 | haverhill
# Processing Record 4 of Set 5 | praya
# Processing Record 5 of Set 5 | tazovskiy
# Processing Record 6 of Set 5 | calamar
# Processing Record 7 of Set 5 | mizdah
# Processing Record 8 of Set 5 | mollendo
# Processing Record 9 of Set 5 | nema
# Processing Record 10 of Set 5 | bahir dar
# Processing Record 11 of Set 5 | high level
# Processing Record 12 of Set 5 | ancud
# Processing Record 13 of Set 5 | bonavista
# Processing Record 14 of Set 5 | borba
# Processing Record 15 of Set 5 | kloulklubed
# Processing Record 16 of Set 5 | tammisaari
# Processing Record 17 of Set 5 | juneau
# Processing Record 18 of Set 5 | leningradskiy
# Processing Record 19 of Set 5 | ust-nera
# Processing Record 20 of Set 5 | kodinsk
# Processing Record 21 of Set 5 | mazamari
# Processing Record 22 of Set 5 | east london
# Processing Record 23 of Set 5 | whitehorse
# Processing Record 24 of Set 5 | te anau
# Processing Record 25 of Set 5 | alenquer
# Processing Record 26 of Set 5 | bam
# Processing Record 27 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | uk
# City not found. Skipping...
# Processing Record 30 of Set 5 | bowen
# Processing Record 31 of Set 5 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 5 | oussouye
# Processing Record 35 of Set 5 | avera
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | beruwala
# Processing Record 38 of Set 5 | pabna
# Processing Record 39 of Set 5 | batsfjord
# Processing Record 40 of Set 5 | tuatapere
# Processing Record 41 of Set 5 | chokurdakh
# Processing Record 42 of Set 5 | tiznit
# Processing Record 43 of Set 5 | mombetsu
# Processing Record 44 of Set 5 | ye
# City not found. Skipping...
# Processing Record 45 of Set 5 | syasstroy
# Processing Record 46 of Set 5 | atambua
# Processing Record 47 of Set 5 | lao cai
# Processing Record 48 of Set 5 | safranbolu
# Processing Record 49 of Set 5 | conakry
# Processing Record 50 of Set 5 | trincomalee
# Processing Record 1 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 6 | turbiv
# Processing Record 3 of Set 6 | naze
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | minot
# Processing Record 6 of Set 6 | samarai
# Processing Record 7 of Set 6 | gasa
# Processing Record 8 of Set 6 | beloha
# Processing Record 9 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 6 | beboto
# Processing Record 11 of Set 6 | ewa beach
# Processing Record 12 of Set 6 | luzhou
# Processing Record 13 of Set 6 | severomorsk
# Processing Record 14 of Set 6 | abay
# Processing Record 15 of Set 6 | ciudad bolivar
# Processing Record 16 of Set 6 | manzanillo
# Processing Record 17 of Set 6 | camacha
# Processing Record 18 of Set 6 | seoul
# Processing Record 19 of Set 6 | tokoroa
# Processing Record 20 of Set 6 | zhanaozen
# Processing Record 21 of Set 6 | saryozek
# Processing Record 22 of Set 6 | pandamatenga
# Processing Record 23 of Set 6 | neyvo-shaytanskiy
# Processing Record 24 of Set 6 | mayo
# Processing Record 25 of Set 6 | manokwari
# Processing Record 26 of Set 6 | kudahuvadhoo
# Processing Record 27 of Set 6 | jiuquan
# Processing Record 28 of Set 6 | hofn
# Processing Record 29 of Set 6 | wonthaggi
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | dunedin
# Processing Record 32 of Set 6 | tasiilaq
# Processing Record 33 of Set 6 | katobu
# Processing Record 34 of Set 6 | baglung
# Processing Record 35 of Set 6 | the pas
# Processing Record 36 of Set 6 | ous
# Processing Record 37 of Set 6 | dombas
# Processing Record 38 of Set 6 | tchollire
# Processing Record 39 of Set 6 | la ronge
# Processing Record 40 of Set 6 | granadilla de abona
# Processing Record 41 of Set 6 | warrnambool
# Processing Record 42 of Set 6 | kralendijk
# Processing Record 43 of Set 6 | ulladulla
# Processing Record 44 of Set 6 | boende
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | alberton
# Processing Record 47 of Set 6 | skorodnoye
# Processing Record 48 of Set 6 | lima
# Processing Record 49 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 6 | ojinaga
# Processing Record 1 of Set 7 | kahului
# Processing Record 2 of Set 7 | pokhara
# Processing Record 3 of Set 7 | goderich
# Processing Record 4 of Set 7 | dicabisagan
# Processing Record 5 of Set 7 | namibe
# Processing Record 6 of Set 7 | cartagena
# Processing Record 7 of Set 7 | atagay
# Processing Record 8 of Set 7 | bemidji
# Processing Record 9 of Set 7 | borovskiy
# Processing Record 10 of Set 7 | tancanhuitz
# Processing Record 11 of Set 7 | taitung
# Processing Record 12 of Set 7 | lloydminster
# Processing Record 13 of Set 7 | vila
# Processing Record 14 of Set 7 | muroto
# Processing Record 15 of Set 7 | oyama
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | ilulissat
# Processing Record 18 of Set 7 | havelock
# Processing Record 19 of Set 7 | uarini
# Processing Record 20 of Set 7 | cheney
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | madimba
# Processing Record 23 of Set 7 | kysyl-syr
# Processing Record 24 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 7 | paamiut
# Processing Record 26 of Set 7 | portland
# Processing Record 27 of Set 7 | altamira
# Processing Record 28 of Set 7 | kannur
# Processing Record 29 of Set 7 | san cristobal
# Processing Record 30 of Set 7 | portales
# Processing Record 31 of Set 7 | jadu
# Processing Record 32 of Set 7 | meulaboh
# Processing Record 33 of Set 7 | vanimo
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | talcahuano
# Processing Record 36 of Set 7 | indianola
# Processing Record 37 of Set 7 | daru
# Processing Record 38 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 7 | sinnamary
# Processing Record 40 of Set 7 | sartell
# Processing Record 41 of Set 7 | kavieng
# Processing Record 42 of Set 7 | asau
# Processing Record 43 of Set 7 | itaqui
# Processing Record 44 of Set 7 | port blair
# Processing Record 45 of Set 7 | perpignan
# Processing Record 46 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 7 | varhaug
# Processing Record 48 of Set 7 | sao francisco do sul
# Processing Record 49 of Set 7 | lautaro
# Processing Record 50 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 8 | vredendal
# Processing Record 2 of Set 8 | great yarmouth
# Processing Record 3 of Set 8 | gushikawa
# Processing Record 4 of Set 8 | san policarpo
# Processing Record 5 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 6 of Set 8 | lisieux
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | silifke
# Processing Record 9 of Set 8 | leninskoye
# Processing Record 10 of Set 8 | upernavik
# Processing Record 11 of Set 8 | mitsamiouli
# Processing Record 12 of Set 8 | sola
# Processing Record 13 of Set 8 | vinh
# Processing Record 14 of Set 8 | praia da vitoria
# Processing Record 15 of Set 8 | prince rupert
# Processing Record 16 of Set 8 | tautira
# Processing Record 17 of Set 8 | usoke
# Processing Record 18 of Set 8 | miguel alves
# Processing Record 19 of Set 8 | westport
# Processing Record 20 of Set 8 | tilichiki
# Processing Record 21 of Set 8 | niono
# Processing Record 22 of Set 8 | mishelevka
# Processing Record 23 of Set 8 | mezen
# Processing Record 24 of Set 8 | harrisonville
# Processing Record 25 of Set 8 | haines junction
# Processing Record 26 of Set 8 | moss point
# Processing Record 27 of Set 8 | flinders
# Processing Record 28 of Set 8 | mikun
# Processing Record 29 of Set 8 | knysna
# Processing Record 30 of Set 8 | port macquarie
# Processing Record 31 of Set 8 | chino valley
# Processing Record 32 of Set 8 | pasni
# Processing Record 33 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 8 | kaitangata
# Processing Record 35 of Set 8 | bolshaya rechka
# Processing Record 36 of Set 8 | vidim
# Processing Record 37 of Set 8 | bambous virieux
# Processing Record 38 of Set 8 | luderitz
# Processing Record 39 of Set 8 | berlevag
# Processing Record 40 of Set 8 | cap malheureux
# Processing Record 41 of Set 8 | mogadishu
# Processing Record 42 of Set 8 | sidhi
# Processing Record 43 of Set 8 | gamba
# Processing Record 44 of Set 8 | uyuni
# Processing Record 45 of Set 8 | pemangkat
# Processing Record 46 of Set 8 | andenes
# Processing Record 47 of Set 8 | jacareacanga
# Processing Record 48 of Set 8 | pechenga
# Processing Record 49 of Set 8 | santa barbara
# Processing Record 50 of Set 8 | perth
# Processing Record 1 of Set 9 | uthal
# Processing Record 2 of Set 9 | pevek
# Processing Record 3 of Set 9 | longyearbyen
# Processing Record 4 of Set 9 | soria
# Processing Record 5 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | fortuna
# Processing Record 8 of Set 9 | neuquen
# Processing Record 9 of Set 9 | inuvik
# Processing Record 10 of Set 9 | bull savanna
# Processing Record 11 of Set 9 | sawakin
# Processing Record 12 of Set 9 | russell
# Processing Record 13 of Set 9 | port lincoln
# Processing Record 14 of Set 9 | bonnyville
# Processing Record 15 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 16 of Set 9 | sa kaeo
# Processing Record 17 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 9 | lac du bonnet
# Processing Record 19 of Set 9 | victor harbor
# Processing Record 20 of Set 9 | vardo
# Processing Record 21 of Set 9 | millinocket
# Processing Record 22 of Set 9 | foumban
# Processing Record 23 of Set 9 | necochea
# Processing Record 24 of Set 9 | ransang
# Processing Record 25 of Set 9 | henties bay
# Processing Record 26 of Set 9 | haimen
# Processing Record 27 of Set 9 | ormara
# Processing Record 28 of Set 9 | dombarovskiy
# Processing Record 29 of Set 9 | shahr-e babak
# Processing Record 30 of Set 9 | salalah
# Processing Record 31 of Set 9 | road town
# Processing Record 32 of Set 9 | huilong
# Processing Record 33 of Set 9 | shilovo
# Processing Record 34 of Set 9 | ahipara
# Processing Record 35 of Set 9 | hami
# Processing Record 36 of Set 9 | skoghall
# Processing Record 37 of Set 9 | nhulunbuy
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | yar-sale
# Processing Record 40 of Set 9 | merauke
# Processing Record 41 of Set 9 | ulundi
# Processing Record 42 of Set 9 | jatai
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | akyab
# Processing Record 45 of Set 9 | usinsk
# Processing Record 46 of Set 9 | nago
# Processing Record 47 of Set 9 | tessalit
# Processing Record 48 of Set 9 | saint-augustin
# Processing Record 49 of Set 9 | san jeronimo
# Processing Record 50 of Set 9 | nishihara
# Processing Record 1 of Set 10 | cayenne
# Processing Record 2 of Set 10 | eyl
# Processing Record 3 of Set 10 | belyy yar
# Processing Record 4 of Set 10 | bouna
# Processing Record 5 of Set 10 | lavrentiya
# Processing Record 6 of Set 10 | ilheus
# Processing Record 7 of Set 10 | miracema
# Processing Record 8 of Set 10 | kalmunai
# Processing Record 9 of Set 10 | suileng
# Processing Record 10 of Set 10 | ekibastuz
# Processing Record 11 of Set 10 | bandarbeyla
# Processing Record 12 of Set 10 | colorines
# Processing Record 13 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 10 | matiguas
# Processing Record 15 of Set 10 | escanaba
# Processing Record 16 of Set 10 | tres arroyos
# Processing Record 17 of Set 10 | eenhana
# Processing Record 18 of Set 10 | korcula
# Processing Record 19 of Set 10 | port hedland
# Processing Record 20 of Set 10 | murygino
# Processing Record 21 of Set 10 | lalganj
# Processing Record 22 of Set 10 | new glasgow
# Processing Record 23 of Set 10 | kananga
# Processing Record 24 of Set 10 | kamaishi
# Processing Record 25 of Set 10 | marbella
# Processing Record 26 of Set 10 | solano
# Processing Record 27 of Set 10 | aldan
# Processing Record 28 of Set 10 | wanning
# Processing Record 29 of Set 10 | mindelo
# Processing Record 30 of Set 10 | omsukchan
# Processing Record 31 of Set 10 | broome
# Processing Record 32 of Set 10 | kearney
# Processing Record 33 of Set 10 | waverly
# Processing Record 34 of Set 10 | ippy
# Processing Record 35 of Set 10 | puerto leguizamo
# Processing Record 36 of Set 10 | santa luzia
# Processing Record 37 of Set 10 | osmena
# Processing Record 38 of Set 10 | okha
# Processing Record 39 of Set 10 | svetlogorsk
# Processing Record 40 of Set 10 | porto novo
# Processing Record 41 of Set 10 | yamada
# Processing Record 42 of Set 10 | kizema
# Processing Record 43 of Set 10 | abu samrah
# Processing Record 44 of Set 10 | chicama
# Processing Record 45 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 10 | alta floresta
# Processing Record 47 of Set 10 | waipawa
# Processing Record 48 of Set 10 | holme
# Processing Record 49 of Set 10 | suntar
# Processing Record 50 of Set 10 | uzventis
# Processing Record 1 of Set 11 | bagdarin
# Processing Record 2 of Set 11 | moyale
# Processing Record 3 of Set 11 | cheremukhovo
# Processing Record 4 of Set 11 | vaitape
# Processing Record 5 of Set 11 | neftegorsk
# Processing Record 6 of Set 11 | virginia beach
# Processing Record 7 of Set 11 | nouakchott
# Processing Record 8 of Set 11 | aquiraz
# Processing Record 9 of Set 11 | gornyy
# Processing Record 10 of Set 11 | constantine
# Processing Record 11 of Set 11 | gweta
# Processing Record 12 of Set 11 | laguna
# Processing Record 13 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 14 of Set 11 | morondava
# Processing Record 15 of Set 11 | atyrau
# Processing Record 16 of Set 11 | grindavik
# Processing Record 17 of Set 11 | diego de almagro
# Processing Record 18 of Set 11 | caravelas
# Processing Record 19 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 11 | hasaki
# Processing Record 21 of Set 11 | kangaatsiaq
# Processing Record 22 of Set 11 | vestmanna
# Processing Record 23 of Set 11 | plainview
# Processing Record 24 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 25 of Set 11 | port moresby
# Processing Record 26 of Set 11 | zhangdian
# Processing Record 27 of Set 11 | excelsior springs
# Processing Record 28 of Set 11 | mwense
# Processing Record 29 of Set 11 | aketi
# Processing Record 30 of Set 11 | leczna
# Processing Record 31 of Set 11 | bilibino
# Processing Record 32 of Set 11 | caramay
# Processing Record 33 of Set 11 | khandyga
# Processing Record 34 of Set 11 | pitimbu
# Processing Record 35 of Set 11 | businga
# Processing Record 36 of Set 11 | aykhal
# Processing Record 37 of Set 11 | jieshi
# Processing Record 38 of Set 11 | komsomolskiy
# Processing Record 39 of Set 11 | togitsu
# Processing Record 40 of Set 11 | richards bay
# Processing Record 41 of Set 11 | swan hill
# Processing Record 42 of Set 11 | beisfjord
# Processing Record 43 of Set 11 | bristol
# Processing Record 44 of Set 11 | palimbang
# Processing Record 45 of Set 11 | kapit
# Processing Record 46 of Set 11 | provideniya
# Processing Record 47 of Set 11 | ca mau
# Processing Record 48 of Set 11 | isla del bosque
# Processing Record 49 of Set 11 | san juan
# Processing Record 50 of Set 11 | ozinki
# Processing Record 1 of Set 12 | haldibari
# Processing Record 2 of Set 12 | emerald
# Processing Record 3 of Set 12 | sena madureira
# Processing Record 4 of Set 12 | paratebueno
# Processing Record 5 of Set 12 | san nicolas
# Processing Record 6 of Set 12 | mapiripan
# Processing Record 7 of Set 12 | quatre cocos
# Processing Record 8 of Set 12 | zatoka
# Processing Record 9 of Set 12 | xining
# Processing Record 10 of Set 12 | horasan
# Processing Record 11 of Set 12 | hay river
# Processing Record 12 of Set 12 | aquin
# Processing Record 13 of Set 12 | acajutla
# Processing Record 14 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 15 of Set 12 | miles city
# Processing Record 16 of Set 12 | sur
# Processing Record 17 of Set 12 | erenhot
# Processing Record 18 of Set 12 | port-gentil
# Processing Record 19 of Set 12 | nizhniy kuranakh
# Processing Record 20 of Set 12 | jiayuguan
# Processing Record 21 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 12 | isiro
# Processing Record 23 of Set 12 | kibala
# Processing Record 24 of Set 12 | makakilo city
# Processing Record 25 of Set 12 | vostok
# Processing Record 26 of Set 12 | rey bouba
# Processing Record 27 of Set 12 | morehead
# Processing Record 28 of Set 12 | shingu
# Processing Record 29 of Set 12 | nurota
# Processing Record 30 of Set 12 | manggar
# Processing Record 31 of Set 12 | west bay
# Processing Record 32 of Set 12 | caohai
# Processing Record 33 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 12 | bow island
# Processing Record 35 of Set 12 | fianarantsoa
# Processing Record 36 of Set 12 | pangnirtung
# Processing Record 37 of Set 12 | ust-kalmanka
# Processing Record 38 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 12 | roald
# Processing Record 40 of Set 12 | sawtell
# Processing Record 41 of Set 12 | coihaique
# Processing Record 42 of Set 12 | linkoping
# Processing Record 43 of Set 12 | san jose
# Processing Record 44 of Set 12 | shakawe
# Processing Record 45 of Set 12 | novikovo
# Processing Record 46 of Set 12 | wenling
# Processing Record 47 of Set 12 | tomakomai
# Processing Record 48 of Set 12 | teeli
# Processing Record 49 of Set 12 | sao bento do sul
# Processing Record 50 of Set 12 | sistranda
# Processing Record 1 of Set 13 | rafaela
# Processing Record 2 of Set 13 | chamrajnagar
# Processing Record 3 of Set 13 | nemuro
# Processing Record 4 of Set 13 | trairi
# Processing Record 5 of Set 13 | calama
# Processing Record 6 of Set 13 | waingapu
# Processing Record 7 of Set 13 | araouane
# Processing Record 8 of Set 13 | monrovia
# Processing Record 9 of Set 13 | poddorye
# Processing Record 10 of Set 13 | igarka
# Processing Record 11 of Set 13 | neklyudovo
# Processing Record 12 of Set 13 | gat
# Processing Record 13 of Set 13 | adamovka
# Processing Record 14 of Set 13 | tshikapa
# Processing Record 15 of Set 13 | paita
# Processing Record 16 of Set 13 | kathu
# Processing Record 17 of Set 13 | fort nelson
# Processing Record 18 of Set 13 | tra vinh
# Processing Record 19 of Set 13 | camana
# Processing Record 20 of Set 13 | tangier
# Processing Record 21 of Set 13 | saint-pierre
# Processing Record 22 of Set 13 | kirakira
# Processing Record 23 of Set 13 | flin flon
# Processing Record 24 of Set 13 | oranjemund
# Processing Record 25 of Set 13 | srednekolymsk
# Processing Record 26 of Set 13 | bimbo
# Processing Record 27 of Set 13 | hualmay
# Processing Record 28 of Set 13 | roxas
# Processing Record 29 of Set 13 | faya
# Processing Record 30 of Set 13 | constitucion
# Processing Record 31 of Set 13 | yerofey pavlovich
# Processing Record 32 of Set 13 | teixeira
# Processing Record 33 of Set 13 | ciras
# City not found. Skipping...
# Processing Record 34 of Set 13 | garowe
# Processing Record 35 of Set 13 | general roca
# Processing Record 36 of Set 13 | winchester
# Processing Record 37 of Set 13 | luanda
# Processing Record 38 of Set 13 | ahero
# Processing Record 39 of Set 13 | blind river
# Processing Record 40 of Set 13 | gopalpur
# Processing Record 41 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 13 | coquimbo
# Processing Record 43 of Set 13 | belaya gora
# Processing Record 44 of Set 13 | wattegama
# Processing Record 45 of Set 13 | salina
# Processing Record 46 of Set 13 | tungor
# Processing Record 47 of Set 13 | sept-iles
# Processing Record 48 of Set 13 | lagoa
# Processing Record 49 of Set 13 | mantua
# Processing Record 50 of Set 13 | grants
# Processing Record 1 of Set 14 | mackay
# Processing Record 2 of Set 14 | pahrump
# Processing Record 3 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 14 | tezu
# Processing Record 5 of Set 14 | sarkand
# Processing Record 6 of Set 14 | les ponts-de-ce
# Processing Record 7 of Set 14 | puerto del rosario
# Processing Record 8 of Set 14 | christchurch
# Processing Record 9 of Set 14 | revelstoke
# Processing Record 10 of Set 14 | yulara
# Processing Record 11 of Set 14 | banda aceh
# Processing Record 12 of Set 14 | teya
# Processing Record 13 of Set 14 | nexo
# Processing Record 14 of Set 14 | aldine
# Processing Record 15 of Set 14 | rawlins
# Processing Record 16 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 14 | deputatskiy
# Processing Record 18 of Set 14 | olga
# Processing Record 19 of Set 14 | araruama
# Processing Record 20 of Set 14 | carman
# Processing Record 21 of Set 14 | soligalich
# Processing Record 22 of Set 14 | kapoeta
# Processing Record 23 of Set 14 | cadereyta
# Processing Record 24 of Set 14 | mirabela
# Processing Record 25 of Set 14 | kiev
# Processing Record 26 of Set 14 | visby
# Processing Record 27 of Set 14 | kon tum
# Processing Record 28 of Set 14 | lugovoy
# Processing Record 29 of Set 14 | oranjestad
# Processing Record 30 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 31 of Set 14 | karratha
# Processing Record 32 of Set 14 | hecelchakan
# Processing Record 33 of Set 14 | coahuayana
# Processing Record 34 of Set 14 | agfalva
# Processing Record 35 of Set 14 | okhotsk
# Processing Record 36 of Set 14 | kishi
# Processing Record 37 of Set 14 | acapulco
# Processing Record 38 of Set 14 | cervo
# Processing Record 39 of Set 14 | nyurba
# Processing Record 40 of Set 14 | clonakilty
# Processing Record 41 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 42 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 43 of Set 14 | launceston
# Processing Record 44 of Set 14 | laibin
# Processing Record 45 of Set 14 | luena
# Processing Record 46 of Set 14 | fuerte olimpo
# Processing Record 47 of Set 14 | esna
# Processing Record 48 of Set 14 | kelvington
# Processing Record 49 of Set 14 | ostrovskoye
# Processing Record 50 of Set 14 | vogan
# Processing Record 1 of Set 15 | ugoofaaru
# Processing Record 2 of Set 15 | point fortin
# Processing Record 3 of Set 15 | gua musang
# Processing Record 4 of Set 15 | konakovo
# Processing Record 5 of Set 15 | half moon bay
# Processing Record 6 of Set 15 | dezful
# Processing Record 7 of Set 15 | santa pola
# Processing Record 8 of Set 15 | harper
# Processing Record 9 of Set 15 | anzio
# Processing Record 10 of Set 15 | shenjiamen
# Processing Record 11 of Set 15 | chapeco
# Processing Record 12 of Set 15 | kalavrita
# City not found. Skipping...
# Processing Record 13 of Set 15 | skerries
# Processing Record 14 of Set 15 | rocha
# Processing Record 15 of Set 15 | ibra
# Processing Record 16 of Set 15 | columbia
# Processing Record 17 of Set 15 | bela palanka
# Processing Record 18 of Set 15 | chiang klang
# Processing Record 19 of Set 15 | kieta
# Processing Record 20 of Set 15 | cravo norte
# Processing Record 21 of Set 15 | hohhot
# Processing Record 22 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 15 | maraa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
new_city_data_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current description"]
city_data_df=city_data_df[new_city_data_order]
city_data_df.head(10)
# Out:
#                    City Country    Lat     Lng  Max Temp  Humidity  \
# 0          Punta Arenas      CL -53.15  -70.92     57.20        47
# 1                 Kapaa      US  22.08 -159.32     78.80        65
# 2               Peniche      PT  39.36   -9.38     60.01        81
# 3  Vila Franca Do Campo      PT  37.72  -25.43     59.00        72
# 4               Ushuaia      AR -54.80  -68.30     50.00        61
# 5              Mae Chan      TH  20.15   99.85     60.80        93
# 6             Egvekinot      RU  66.32 -179.17      2.64        85
# 7                  Brae      GB  60.40   -1.35     41.00        86
# 8                  Atar      MR  20.52  -13.05     75.18        20
# 9                 Simav      TR  39.09   28.98     41.90        64
#
#    Cloudiness  Wind Speed Current description
# 0          75       47.20          light rain
# 1          75        6.93       broken clouds
# 2          93        4.00     overcast clouds
# 3          20       23.04          few clouds
# 4          75       28.86          light rain
# 5           0        3.36           clear sky
# 6          20        8.93          few clouds
# 7          20       12.75          few clouds
# 8           1        4.12           clear sky
# 9          20        4.18          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
